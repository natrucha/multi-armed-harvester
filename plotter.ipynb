# %%
## Notebook to plot things 
#  each cell is set up for a different type of plot, find what you need and add appropriate input

# %%
import csv
import math
import numpy as np

# %matplotlib notebook        
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   # plot in 3D

# %%
# notes and documentation
# moving the legend around https://stackoverflow.com/questions/4700614/how-to-put-the-legend-outside-the-plot

# %%
# display options

# from https://stackoverflow.com/questions/21008858/formatting-floats-in-a-numpy-array
# function to display floats in numpy arrays to 3 decimals of precision (does not affect computation)
float_formatter = "{:.3f}".format
# print all numpy array floats to 3 decimal precision
np.set_printoptions(formatter={'float_kind':float_formatter})

# %%
# # CSV data
# # folder name
# folder = './csv_files/'

# date   = '20240117'

# tested_CRA = ['1/1/1', '1/2/2', '2/1/2', '1/3/3', '3/1/3', '2/2/4', '2/3/6', '3/2/6', '3/3/9']
# # as ints for looping
# file_name_CR = [11, 12, 21, 13, 31, 22, 23, 32, 33]

# # x-axis ticks
# x = np.arange(len(tested_CRA))

# runs_in_file = 100 # check the number of rows in any of the CSVs

# # csv file ending
# file_type = '.csv'

# # colors
# # see https://personal.sron.nl/~pault/#sec:qualitative
# # and a different ben (https://stats.stackexchange.com/users/9311/a-different-ben), "Best" series of colors to use for differentiating series in publication-quality plots, URL (version: 2021-03-03): https://stats.stackexchange.com/q/118259
# color_array = ['#228833', '#4477AA', '#66CCEE', '#AA3377', '#EE6677', '#CCBB44', '#BBBBBB']

# %%
# # obtain data from CSV to compare hight vs. fruit row partitioning
# data_file_start = [date+'_2022_data_fruit_CR', date+'_2022_data_height_CR']

# V_run = '_V20'

# # Equal number of fruits in each row partition
# # arrays to save the FPE and FPT of each C/R/C*R configuration
# FPE_array_fruits = np.zeros((len(tested_CRA), runs_in_file))
# FPT_array_fruits = np.zeros((len(tested_CRA), runs_in_file))

# # arrays to save the mean and variance of FPE and FPT of each C/R/C*R configuration
# FPE_avg_array_fruits = np.zeros(len(tested_CRA))
# FPE_std_array_fruits = np.zeros(len(tested_CRA))
# FPT_avg_array_fruits = np.zeros(len(tested_CRA))
# FPT_std_array_fruits = np.zeros(len(tested_CRA))

# # Equal height for each row partition
# # arrays to save the FPE and FPT of each C/R/C*R configuration
# FPE_array_height = np.zeros((len(tested_CRA), runs_in_file))
# FPT_array_height = np.zeros((len(tested_CRA), runs_in_file))

# # arrays to save the mean and variance of FPE and FPT of each C/R/C*R configuration
# FPE_avg_array_height = np.zeros(len(tested_CRA))
# FPE_std_array_height = np.zeros(len(tested_CRA))
# FPT_avg_array_height = np.zeros(len(tested_CRA))
# FPT_std_array_height = np.zeros(len(tested_CRA))

# cr_index = 0

# # only look at C/R combinations in the file_name_CR array
# for cr in file_name_CR:
#     for file_i in range(len(data_file_start)):
#         file_name = folder + data_file_start[file_i] + str(cr) + V_run + file_type
#         print('\nThe file being opened is', file_name) 

#         with open(file_name) as csvfile:

#             reader = csv.reader(csvfile, delimiter=',', quoting=csv.QUOTE_NONNUMERIC)
#             row_i = 0

#             for row in reader:
#                 if file_i == 0:
#                     # row by fruit
#                     FPE_array_fruits[cr_index,row_i] = row[8]
#                     FPT_array_fruits[cr_index,row_i] = row[10]
# #                     print('By fruit: for V %s, row %d' %(V[V_i], row_i))
# #                     print('FPE value %3.3f and FPT value %3.3f' %(row[8], row[10]))

#                 elif file_i == 1:
#                     # row by height
#                     FPE_array_height[cr_index,row_i] = row[8]
#                     FPT_array_height[cr_index,row_i] = row[10]
# #                     print('By hieght: for V %d, row %d' %(v, row_i))
# #                     print('FPE value %3.3f and FPT value %3.3f' %(row[7], row[9]))

#                 row_i += 1

#         # all files for this CR combo have been processed, calculate the average and standard deviation for them
#         FPE_avg_array_fruits[cr_index] = np.average(FPE_array_fruits[cr_index,:])
#         FPE_std_array_fruits[cr_index] = np.std(FPE_array_fruits[cr_index,:])
#         FPT_avg_array_fruits[cr_index] = np.average(FPT_array_fruits[cr_index,:])
#         FPT_std_array_fruits[cr_index] = np.std(FPT_array_fruits[cr_index,:])

#         FPE_avg_array_height[cr_index] = np.average(FPE_array_height[cr_index,:])
#         FPE_std_array_height[cr_index] = np.std(FPE_array_height[cr_index,:])
#         FPT_avg_array_height[cr_index] = np.average(FPT_array_height[cr_index,:])
#         FPT_std_array_height[cr_index] = np.std(FPT_array_height[cr_index,:])

#     cr_index += 1
    
# print('\n\nFor equal fruit')
# print('------------------------------------------------------')
# print('Average FPE values:\n', FPE_avg_array_fruits, '\n')  
# print('Standard dev FPE values:\n', FPE_std_array_fruits, '\n')  
# print('Average FPT values:\n', FPT_avg_array_fruits, '\n')  
# print('Standard dev FPT values:\n', FPT_std_array_fruits)  

# print('\n\nFor equal height')
# print('------------------------------------------------------')
# print('Average FPE values:\n', FPE_avg_array_height, '\n')
# print('Standard dev FPE values:\n', FPE_std_array_height, '\n')
# print('Average FPT values:\n', FPT_avg_array_height, '\n')
# print('Standard dev FPT values:\n', FPT_std_array_height)

# %%
# #### Plot comparison of row partitioning height vs. fruit

# n_subplots = 2

# fig, axs = plt.subplots(n_subplots, 1)
# ## want subplots to stack in columns so they can be compared, see
# ## see https://matplotlib.org/stable/gallery/lines_bars_and_markers/cohere.html#sphx-glr-gallery-lines-bars-and-markers-cohere-py

# axs[0].plot(x , FPE_avg_array_height, color=color_array[1], marker='s', markersize=5, linewidth=2, label='equal height')
# axs[0].errorbar(x , FPE_avg_array_height, yerr=FPE_std_array_height, capsize=5, color=color_array[1])
# axs[0].plot(x , FPE_avg_array_fruits, color=color_array[4], marker='s', markersize=5, linewidth=2, label='equal fruit')
# axs[0].errorbar(x , FPE_avg_array_fruits, yerr=FPE_std_array_fruits, capsize=3, color=color_array[4])
# ## Labels and grid for ax0
# # axs[0].set_xlabel('No. Rows x No. Columns')
# axs[0].set_ylabel('FPE (%)')
# axs[0].grid(True)

# # axs[0].set_title('Results from running a min makespan MIP model \n to pick a vehicle velocity that results in the best FPT \n when FPE is at least 95%')
# # axs[0].set_title(' ')
# legend = axs[0].legend(bbox_to_anchor=(1., 1.),loc='best', fontsize=15)

# axs[1].plot(x , FPT_avg_array_height, color=color_array[1], marker='s', markersize=5, linewidth=2, label='equal height')
# axs[1].errorbar(x , FPT_avg_array_height, yerr=FPT_std_array_height, capsize=5, color=color_array[1])
# axs[1].plot(x , FPT_avg_array_fruits, color=color_array[4], marker='s', markersize=5, linewidth=2, label='equal fruit')
# axs[1].errorbar(x , FPT_avg_array_fruits, yerr=FPT_std_array_fruits, capsize=3, color=color_array[4])
# # axs[1].set_xlabel('Columns/Rows/Total Arms')
# axs[1].grid(True)
# axs[1].set_ylabel('FPT (fruits/s)')

# axs[n_subplots-1].set_xlabel('No. columns/rows/arms')

# # plt.xticks(x, tested_CRA)#, rotation='vertical')
# axs[0].set_xticks(x, tested_CRA, rotation='vertical')
# axs[1].set_xticks(x, tested_CRA, rotation='vertical')

# fig.tight_layout()

# # # file_name = './plots/density_fpe_fpt_20220623.png'
# # # print('Saving plot of FPT and FPE vs density in', file_name)
# # # plt.savefig(file_name,dpi=300)
# plt.show()

# %%
# # # read a CSV file comparing V FPE and FPT for each C/R/C*R setting
# data_file_start = date+'_2022_data_fruit_CR'

# V = ['5', '10', '20', 'best']

# # number of fruits equal
# FPE_array_fruits = np.zeros((len(tested_CRA), runs_in_file, len(V)))
# FPT_array_fruits = np.zeros((len(tested_CRA), runs_in_file, len(V)))

# FPE_avg_array_fruits = np.zeros((len(tested_CRA), len(V)))
# FPE_std_array_fruits = np.zeros((len(tested_CRA), len(V)))
# FPT_avg_array_fruits = np.zeros((len(tested_CRA), len(V)))
# FPT_std_array_fruits = np.zeros((len(tested_CRA), len(V)))

# cr_index = 0

# # only column increase combinations
# for cr in file_name_CR:
#     for V_i in range(len(V)):
#         file_name = folder + data_file_start + str(cr) + '_V' + V[V_i] + file_type
#         print('\nThe file being opened is', file_name) 

#         with open(file_name) as csvfile:

#             reader = csv.reader(csvfile, delimiter=',', quoting=csv.QUOTE_NONNUMERIC)
#             row_i = 0

#             for row in reader:
#                 FPE_array_fruits[cr_index,row_i, V_i] = row[8]
#                 FPT_array_fruits[cr_index,row_i, V_i] = row[10]
# #                 print('By fruit: for V %s, row %d' %(V[V_i], row_i))
# #                 print('FPE value %3.3f and FPT value %3.3f' %(row[8], row[10]))

#                 row_i += 1

#         # all files for this V have been processed, calculate the average and standard deviation for them
#         FPE_avg_array_fruits[cr_index,V_i] = np.average(FPE_array_fruits[cr_index,:,V_i])
#         FPE_std_array_fruits[cr_index,V_i] = np.std(FPE_array_fruits[cr_index,:,V_i])
#         FPT_avg_array_fruits[cr_index,V_i] = np.average(FPT_array_fruits[cr_index,:,V_i])
#         FPT_std_array_fruits[cr_index,V_i] = np.std(FPT_array_fruits[cr_index,:,V_i])

#     cr_index += 1

    
# print('\n\nFor equal fruit')
# print('------------------------------------------------------')
# print('Average FPE values:\n', FPE_avg_array_fruits, '\n')  
# print('Standard dev FPE values:\n', FPE_std_array_fruits, '\n')  
# print('Average FPT values:\n', FPT_avg_array_fruits, '\n')  
# print('Standard dev FPT values:\n', FPT_std_array_fruits)

# %%
# # ## Line subplots

# n_subplots = 2

# fig, axs = plt.subplots(n_subplots, 1)
# ## want subplots to stack in columns so they can be compared, see
# ## see https://matplotlib.org/stable/gallery/lines_bars_and_markers/cohere.html#sphx-glr-gallery-lines-bars-and-markers-cohere-py
# for V_i in range(len(V)):
#     if V_i < 3:
#         line_style = '--'
#         line_width = 1
#         cap_size   = 3
#     else:
#         line_style = '-'
#         line_width = 2
#         cap_size   = 5
        
#     axs[0].plot(x , FPE_avg_array_fruits[:,V_i], color=color_array[V_i], marker='s', markersize=5, linestyle=line_style, linewidth=line_width, label='V = ' + V[V_i])
#     axs[0].errorbar(x , FPE_avg_array_fruits[:,V_i], yerr=FPE_std_array_fruits[:,V_i], color=color_array[V_i], linestyle=line_style, linewidth=line_width, capsize=cap_size)
    
# ## Labels and grid for ax0
# # axs[0].set_xlabel('No. Rows x No. Columns')
# axs[0].set_ylabel('FPE (%)')
# axs[0].grid(True)

# # axs[0].set_title('Results from running a min makespan MIP model \n to pick a vehicle velocity that results in the best FPT \n when FPE is at least 95%')
# # axs[0].set_title(' ')
# legend = axs[0].legend(bbox_to_anchor=(1., 1.3),loc='best', fontsize=15)

# for V_i in range(len(V)):
#     if V_i < 3:
#         line_style = '--'
#         line_width = 1
#         cap_size   = 3
#     else:
#         line_style = '-'
#         line_width = 2
#         cap_size   = 5
        
#     axs[1].plot(x, FPT_avg_array_fruits[:,V_i], color=color_array[V_i], marker='s', markersize=5, linestyle=line_style, linewidth=line_width)
#     axs[1].errorbar(x, FPT_avg_array_fruits[:,V_i], yerr=FPT_std_array_fruits[:,V_i], color=color_array[V_i],linestyle=line_style, linewidth=line_width, capsize=cap_size)
# # axs[1].set_xlabel('Columns/Rows/Total Arms')
# axs[1].grid(True)
# axs[1].set_ylabel('FPT (fruits/s)')
# # legend = axs[1].legend(bbox_to_anchor=(1., 1),loc='best', fontsize=15)

# axs[n_subplots-1].set_xlabel('No. columns/rows/arms')

# # plt.xticks(x, tested_CRA)#, rotation='vertical')
# axs[0].set_xticks(x, tested_CRA, rotation='vertical')
# axs[1].set_xticks(x, tested_CRA, rotation='vertical')

# fig.tight_layout()

# # # file_name = './plots/density_fpe_fpt_20220623.png'
# # # print('Saving plot of FPT and FPE vs density in', file_name)
# # # plt.savefig(file_name,dpi=300)
# plt.show()

# %%
# # ## Line subplots

# n_subplots = 2

# fig, axs = plt.subplots(n_subplots, 1)
# ## want subplots to stack in columns so they can be compared, see
# ## see https://matplotlib.org/stable/gallery/lines_bars_and_markers/cohere.html#sphx-glr-gallery-lines-bars-and-markers-cohere-py
# for V_i in range(len(V)):
# #     axs[0].plot(x , FPE_avg_array_height[:,V_i], color='#4b0082', marker='s', markersize=5, linewidth=2, label='equal height')
# #     axs[0].errorbar(x , FPE_avg_array_height[:,V_i], yerr=FPE_std_array_height[:,V_i], color='#4b0082')
#     if V_i < 3:
#         line_style  = '--'
#         line_width = 1
#     else:
#         line_style  = '-'
#         line_width = 2
        
#     axs[0].plot(x , FPE_avg_array_fruits[:,V_i], color=color_array[V_i], marker='s', markersize=5, linestyle=line_style, linewidth=line_width, label='V = ' + V[V_i])
#     axs[0].errorbar(x , FPE_avg_array_fruits[:,V_i], yerr=FPE_std_array_fruits[:,V_i], color=color_array[V_i], linestyle=line_style, linewidth=line_width,)
# # axs[0].plot(x, hsm_fpe_mean, color='deepskyblue', marker='o', markersize=4, linewidth=2, label='HSM')
# # axs[0].errorbar(x, hsm_fpe_mean, yerr=hsm_fpe_std, color='deepskyblue')
# # axs[0].plot(x, lsm_fpe_mean, color='darkgreen', marker='o', markersize=4, linewidth=2, label='LSM')
# # axs[0].errorbar(x, lsm_fpe_mean, yerr=lsm_fpe_std, color='darkgreen')
# # axs[0].plot(x1, hs3_fpe_mean, color='#4b0082', marker='o', markersize=6, linewidth=3)
# # axs[0].errorbar(x1, hs3_fpe_mean, yerr=hs3_fpe_std, color='#4b0082')
# # axs[0].plot(x1, ls3_fpe_mean, color='r', marker='o', markersize=6, linewidth=3)
# # axs[0].errorbar(x1, ls3_fpe_mean, yerr=ls3_fpe_std, color='r')
# # axs[0].plot(x1, hsm3_fpe_mean, color='gold', marker='o', markersize=6, linewidth=3, label='HSM3')
# # axs[0].errorbar(x1, hsm3_fpe_mean, yerr=hsm3_fpe_std, color='gold')
# # axs[0].plot(x1, lsm3_fpe_mean, color='darkmagenta', marker='o', markersize=6, linewidth=3, label='LSM3')
# # axs[0].errorbar(x1, lsm3_fpe_mean, yerr=lsm3_fpe_std, color='darkmagenta')

# ## Labels and grid for ax0
# # axs[0].set_xlabel('No. Rows x No. Columns')
# axs[0].set_ylabel('FPE (%)')
# axs[0].grid(True)

# # axs[0].set_title('Results from running a min makespan MIP model \n to pick a vehicle velocity that results in the best FPT \n when FPE is at least 95%')
# # axs[0].set_title(' ')
# legend = axs[0].legend(bbox_to_anchor=(1., 1.3),loc='best', fontsize=15)

# for V_i in range(len(V)):
#     if V_i < 3:
#         line_style  = '--'
#         line_width = 1
#     else:
#         line_style  = '-'
#         line_width = 2
# #     axs[1].plot(x, FPT_avg_array_height[:,V_i], color='#4b0082', marker='s', markersize=5, linewidth=2)
# #     axs[1].errorbar(x, FPT_avg_array_height[:,V_i], yerr=FPT_std_array_height[:,V_i], color='#4b0082')
#     axs[1].plot(x, FPT_avg_array_fruits[:,V_i], color=color_array[V_i], marker='s', markersize=5, linestyle=line_style, linewidth=line_width)
#     axs[1].errorbar(x, FPT_avg_array_fruits[:,V_i], yerr=FPT_std_array_fruits[:,V_i], color=color_array[V_i],linestyle=line_style, linewidth=line_width)
# # axs[1].set_xlabel('Columns/Rows/Total Arms')
# axs[1].grid(True)
# axs[1].set_ylabel('FPT (fruits/s)')
# # legend = axs[1].legend(bbox_to_anchor=(1., 1),loc='best', fontsize=15)

# # axs[2].plot(x, t1_1, color='#4b0082', marker='o', markersize=6, linewidth=3)
# # axs[2].errorbar(x, t1_1, yerr=t1_1_e, color='#4b0082')
# # axs[2].plot(x, t2_1, color='r', marker='o', markersize=6, linewidth=3)
# # axs[2].errorbar(x, t2_1, yerr=t2_1_e, color='r')
# # axs[2].plot(x, t3_1, color='deepskyblue', marker='o', markersize=6, linewidth=3)
# # axs[2].errorbar(x, t3_1, yerr=t3_1_e, color='deepskyblue')
# # axs[2].plot(x, t1_2, color='darkgreen', marker='o', markersize=6, linewidth=3)
# # axs[2].errorbar(x, t1_2, yerr=t1_2_e, color='darkgreen')
# # axs[2].plot(x, t1_3, color='gold', marker='o', markersize=6, linewidth=3)
# # axs[2].errorbar(x, t1_3, yerr=t1_3_e, color='gold')
# # axs[2].grid(True)
# # axs[2].set_ylabel('solving time [s] \n(time limit 60 s)')

# # axs[3].plot(x, y4_1, color='#4b0082')
# # axs[3].plot(x, y4_2, color='r')
# # axs[3].plot(x, y4_3, color='#4b0082')
# # axs[3].grid(True)
# # axs[3].set_ylabel('run time [s]')


# axs[n_subplots-1].set_xlabel('No. columns/rows/arms')

# # plt.xticks(x, tested_CRA)#, rotation='vertical')
# axs[0].set_xticks(x, tested_CRA, rotation='vertical')
# axs[1].set_xticks(x, tested_CRA, rotation='vertical')

# fig.tight_layout()

# # # file_name = './plots/density_fpe_fpt_20220623.png'
# # # print('Saving plot of FPT and FPE vs density in', file_name)
# # # plt.savefig(file_name,dpi=300)
# plt.show()

# %%
# ## Two plots with different y-axes within same graph
# # see https://stackoverflow.com/questions/42734109/two-or-more-graphs-in-one-plot-with-different-x-axis-and-y-axis-scales-in-pyth

# fig=plt.figure()
# ax=fig.add_subplot(111, label="1")
# ax2=fig.add_subplot(111, label="2", frame_on=False)

# ax.plot(x, fpe_constV_equalH, color="C0", label='FPE: equal height/row')
# ax.plot(x, fpe_constV_equalN, color="#4b0082", label='FPE: equal No. fruits/row')
# # ax.plot(x, fpe_varV_equalH, color="r", label='varV, equalH')
# # ax.plot(x, fpe_varV_equalN, color="deepskyblue", label='varV, equalN')
# ax.set_xlabel("V (cm/s)", color="k")
# ax.set_ylabel("FPE", color="r")
# ax.tick_params(axis='x', colors="r")
# ax.tick_params(axis='y', colors="r")
# # ax.set_ylim(0.25, 2.2)
# # shrink the size of the plot so the legend can go on the side
# box = ax.get_position()
# ax.set_position([box.x0, box.y0, box.width * 0.7, box.height])
# legend = ax.legend(bbox_to_anchor=(1.1, 0.95), loc='center left', fontsize=12)


# # ax2.scatter(x_values2, y_values2, color="C1")
# ax2.plot(x, fpt_constV_equalH, color="C0", linestyle='dashed', label='FPT: equal height/row')
# ax2.plot(x, fpt_constV_equalN, color="#4b0082", linestyle='dashed', label='FPT: equal No. fruits/row')
# # ax2.plot(x, fpt_varV_equalH, color="r", linestyle='dashed')
# # ax2.plot(x, fpt_varV_equalN, color="deepskyblue", linestyle='dashed')
# ax2.yaxis.tick_right()
# ax2.set_ylabel('FPT (fruits/s)')       
# ax2.yaxis.set_label_position('right') 
# ax2.tick_params(axis='x')
# ax2.tick_params(axis='y')
# # ax2.set_ylim(0.25, 2.2)
# # shrink the size of the plot so the legend can go on the side
# ax2.set_position([box.x0, box.y0, box.width * 0.7, box.height])
# legend2 = ax2.legend(bbox_to_anchor=(1.1, 0.75), loc='center left', fontsize=12)

# plt.show()

# %%
# # # bar plots!

# # # when having two bar plots with seperate y-axis labels (say FPT and FPE)
# fig=plt.figure()
# ax=fig.add_subplot(111, label="1")
# # ax2=fig.add_subplot(111, label="2", frame_on=False)
# # ax3=fig.add_subplot(111, label="3", frame_on=False)
# # ax4=fig.add_subplot(111, label="4", frame_on=False)
# n_axis = 1

# # # needed when the x-data is made up of words (this sets the x-axis coordinates)
# bar_width = 1/n_axis
# index  = np.arange(len(columns)) + (bar_width/2)
# # index2 = index + bar_width
# # index3 = index2 + bar_width
# # index4 = index3 + bar_width

# y_offset = np.zeros(len(columns))

# ax.bar(index, FPE_mean, width=.35, color='navy', label='FPE_mean')
# ax.errorbar(index, FPE_mean, yerr=FPE_std, fmt='o')
# # ax.bar(index, FPT_mean, width=.35, color='seagreen', label='FPT_mean')
# # ax.errorbar(index, FPT_mean, yerr=FPT_std, fmt='o', color='mediumseagreen')
# # ax.bar(index, FPE_mean, bar_width, bottom=y_offset, color='navy', ec = "white")
# # ax2.bar(index2, FPT_mean, bar_width, bottom=y_offset, color='seagreen')
# # ax3.bar(index3, FPE_juan, bar_width, bottom=y_offset, color='mediumblue')
# # ax4.bar(index4, FPT_juan, bar_width, bottom=y_offset, color='mediumseagreen')

# # set x-axis limits so that bars of the two plots can be placed side-by-side correctly 
# ax.set_xlim(0, len(columns))
# # ax2.set_xlim(0, 11)
# # ax2.set_ylim(0, 3.5)
# # ax3.set_xlim(0, 11)
# # ax4.set_xlim(0, 11)
# # ax4.set_ylim(0, 3.5)

# # add the words as the labels for the bars
# # xticks = np.arange(len(columns))
# # xticks2 = np.arange(len(columns))
# ax.set_xticks(index)#xticks)
# ax.set_xticklabels(columns)
# ax.tick_params(axis='x', labelrotation=90)
# ax.set_xlabel("Number of columns and rows")
# # remove x-ticks for the 2nd plot
# # ax2.set_xticks([])
# # ax3.set_xticks([])
# # ax4.set_xticks([])
# # ax4.set_yticks([])

# # Add Bar Labels
# # for c in ax.containers:
# #     ax.bar_label(c)

# # add the label(s) to plot
# ax.set_ylabel("FPE (%)", color="navy")
# # ax.set_ylabel("FPT (fruits/s)", color="seagreen")
# # add ticks and label for the second plot to the right side of the table
# # ax2.set_ylabel("FPT (fruits/s)", color="seagreen")
# # ax2.yaxis.tick_right()
# # ax2.yaxis.set_label_position('right') 

# # # if the labels are getting cut-off
# plt.subplots_adjust(bottom=0.2)

# # ax.grid(True)
# # ax2.grid(True)

# plt.show()

# %%
# Read CSV files of fruit localization data
## Obtain fruit data from the 2022 Field Trip
n_files = 28 

orch_x_list = list()
orch_y_list = list()
orch_z_list = list()

# test for the max value in x, y, and z for all segments
orch_max_x = 0
orch_min_x = 1000
orch_max_y = 0
orch_min_y = 1000
orch_max_z = 0
orch_min_z = 1000

orch_N_list = list() # saves the number of fruits in each segment

csv_folder = './TREE_FRUIT_DATA/apple_data_2022/'

for run_n in range(n_files):
#     print('CSV file number:', run_n)
    if run_n <= 5:
        run_files = '01_42_4_apples_' + str(run_n+1) + '.csv'
    elif run_n <= 10:
        run_files = '46_42_1_apples_' + str(run_n-5) + '.csv'
    elif run_n <= 14:
        run_files = '51_42_2_apples_' + str(run_n-10) + '.csv'
    elif run_n <= 17:
        run_files = '56_42_3_apples_' + str(run_n-14) + '.csv'
    elif run_n <= 18:
        run_files = '30_38_2_apples_1.csv'
        # only one file of this denomination
    elif run_n <= 19:
        # only one file of this denomination
        run_files = '41_42_0_apples_1.csv'
    elif run_n <= 23:
        run_files = '41_42_12_apples_' + str(run_n-19) + '.csv'
    elif run_n <= 27:
        run_files = '50_38_6_apples_' + str(run_n-23) + '.csv'
    else: 
        print('WARNING: There are no more files in the 2022 dataset to run. Defaulting to the last file.')
        run_files = '50_38_6_apples_4.csv'
    
    # name of the CSV file that will be opened
    csv_file = csv_folder + run_files
    
    # init the number of fruits and the list of fruits for this segment
    n_fruit_file = 0
    x_list_file  = list()
    y_list_file  = list()  # need the y-coordinates to separate fruits into their respective segments
    z_list_file  = list()

    # open the file once and later separate into segments (don't have to open it for every segment)
    with open(csv_file) as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quoting=csv.QUOTE_NONNUMERIC)
        for row in reader:
            # the 2022 data is the only data set that has different x, y, z definitions than the rest of the project
            y_list_file.append(row[0]) # length along orchard row
            z_list_file.append(row[1]) # height
            x_list_file.append(row[2]) # height
            
            n_fruit_file += 1
    print('---------------------------------------------------')
    print('For file %d, numbered %s' %(run_n, csv_file))
    print('N in file: %d' %n_fruit_file)
    orch_N_list.append(n_fruit_file)

    # turn the file's list of z-coordinates into an array for easier work
    x = np.array(x_list_file)
    y = np.array(y_list_file)
    z = np.array(z_list_file)
    
    # remove any negative values and start at a min value for the whole orchard segment 
    x_translate = np.amin(x) - 0.01
    x = x - x_translate
    y_translate = np.amin(y) - 0.01
    y = y - y_translate
    z_translate = np.amin(z) - 0.01
    z = z - z_translate
    
    print('the max values for each axis are:\n        x:              y:              z:')
    print('         %3.2f            %3.2f           %3.2f' %(np.amax(x)-0.01, np.amax(y)-0.01, np.amax(z)-0.01))
#     print('the min values for each axis are:\n        x:              y:              z:')
#     print('         %3.2f            %3.2f           %3.2f\n' %(np.amin(x), np.amin(y), np.amin(z)))
    
    orch_x_list.append(x)
    orch_y_list.append(y)
    orch_z_list.append(z)
    
        
# save the number of fruits as an array
N_array    = np.array(orch_N_list)

print('each orchard contains', N_array, 'fruits')
# Out:
# ---------------------------------------------------
# For file 0, numbered ./TREE_FRUIT_DATA/apple_data_2022/01_42_4_apples_1.csv
# N in file: 283
# the max values for each axis are:
#         x:              y:              z:
#          1.84            10.72           2.46
# ---------------------------------------------------
# For file 1, numbered ./TREE_FRUIT_DATA/apple_data_2022/01_42_4_apples_2.csv
# N in file: 223
# the max values for each axis are:
#         x:              y:              z:
#          1.47            10.15           2.19
# ---------------------------------------------------
# For file 2, numbered ./TREE_FRUIT_DATA/apple_data_2022/01_42_4_apples_3.csv
# N in file: 447
# the max values for each axis are:
#         x:              y:              z:
#          2.17            12.36           2.65
# ---------------------------------------------------
# For file 3, numbered ./TREE_FRUIT_DATA/apple_data_2022/01_42_4_apples_4.csv
# N in file: 404
# ...

# %%
# plot fruits in 3D
file_n = 26

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(orch_x_list[file_n], orch_y_list[file_n], orch_z_list[file_n])

ax.set_xlabel('x, into canopy')
ax.set_ylabel('y, along orchard row')
ax.set_zlabel('z, height')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
